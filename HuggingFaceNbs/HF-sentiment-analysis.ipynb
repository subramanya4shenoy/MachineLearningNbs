# %%
from transformers import pipeline

# %%
classifier = pipeline('sentiment-analysis')

# %%
res = classifier('Thanks for the tutorial! In only 1 year we came from  34K models available to almost 300K models, almost 10x increase! 😮')
print(res)
